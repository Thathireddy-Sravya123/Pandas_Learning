# %% [markdown]
# <a href="https://colab.research.google.com/github/Thathireddy-Sravya123/Pandas_Learning/blob/main/PANDAS_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **The process for reading CSV file**

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
imdb_filepath = "/content/drive/MyDrive/Data Sets/imdb_data.csv"

# %%
#read imdb_filepath into pandas dataframe
df = pd.read_csv(imdb_filepath)

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# **Head(n)**

# %%
df.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# ...

# %% [markdown]
# **Tail(n)**

# %%
df.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# ...

# %% [markdown]
# **Columns**

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# **To get only few Columns**

# %%
l=['id' , 'title']
df1 = df[l]
df1
# Out:
#         id                                     title
# 0        1                    Hot Tub Time Machine 2
# 1        2  The Princess Diaries 2: Royal Engagement
# 2        3                                  Whiplash
# 3        4                                   Kahaani
# 4        5                                Marine Boy
# ...    ...                                       ...
# 2995  2996                                   Chasers
# 2996  2997                          We Are the Best!
# 2997  2998                   The Long Kiss Goodnight
# 2998  2999                          Along Came Polly
# 2999  3000                                 Abduction
#
# [3000 rows x 2 columns]

# %% [markdown]
# **To do operations easily on columns we use list**

# %%
list(df.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %% [markdown]
# **Info()** - **It print the basic info of data frame**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# **Rename() - Renaming the column of the dataframe**

# %% [markdown]
# We can do for single column or multiple columns

# %% [markdown]
# We can use inplace = True , only when trying to modify data frame like rename() , drop().

# %%
df.rename(columns={'budget':'Budget' , 'genres':'Genres' , 'id':'Id'} , inplace = True)
df
# Out:
#         Id                              belongs_to_collection    Budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  Genres  \
# ...

# %% [markdown]
# **Describe()** - it is like a personal statistician for your dataset. It includes count, mean, standard deviation, minimum, maximum, and percentiles.

# %%
df.describe()
# Out:
#                 Id        Budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %% [markdown]
# **sort_values():**

# %%
# Sort values in descending order
df.sort_values('runtime', ascending=False)
# Out:
#         Id                              belongs_to_collection    Budget  \
# 1211  1212                                                NaN  18000000
# 1922  1923                                                NaN  31115000
# 523    524                                                NaN  13000000
# 1302  1303                                                NaN  44000000
# 1914  1915                                                NaN  56000000
# ...    ...                                                ...       ...
# 2785  2786                                                NaN         0
# 2865  2866  [{'id': 188197, 'name': 'Cetto La Qualunque - ...   5579750
# 2498  2499  [{'id': 106790, 'name': 'Hooked Collection', '...   3500000
# 1335  1336                                                NaN   6000000
# 2302  2303                                                NaN         0
#
#                                                  Genres homepage    imdb_id  \
# ...

# %% [markdown]
# **Writing a dataframe to a location.** Writing the data frame to location as cvs

# %%
data = {'name': ['Alice', 'Bob', 'Charlie'],
        'age': [25, 30, 35]}
df1 = pd.DataFrame(data)
df1
# Out:
#       name  age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
df.to_csv('newframe.csv', index=True)

# %% [markdown]
# **Loc()** - location
# **iloc()** - index location

# %%
list(df.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %%
#using loc[]
df_50_60 = df.loc[50:60]
df_50_60
# Out:
#     id                              belongs_to_collection     budget  \
# 50  51                                                NaN     560000
# 51  52                                                NaN   12000000
# 52  53                                                NaN          0
# 53  54                                                NaN          0
# 54  55                                                NaN   20000000
# 55  56                                                NaN          0
# 56  57                                                NaN          0
# 57  58  [{'id': 120794, 'name': 'Batman Collection', '...  125000000
# 58  59                                                NaN          0
# 59  60                                                NaN   14000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
#
#                                                genres  \
# 50  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# ...

# %%
df.iloc[50:60]
# Out:
#     id                              belongs_to_collection     budget  \
# 50  51                                                NaN     560000
# 51  52                                                NaN   12000000
# 52  53                                                NaN          0
# 53  54                                                NaN          0
# 54  55                                                NaN   20000000
# 55  56                                                NaN          0
# 56  57                                                NaN          0
# 57  58  [{'id': 120794, 'name': 'Batman Collection', '...  125000000
# 58  59                                                NaN          0
# 59  60                                                NaN   14000000
#
#                                                genres  \
# 50  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 51  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# ...

# %% [markdown]
# **Remember** :
# 1. if u use slicing with columns - loc[]
# 2. if u use slicing without columns - iloc[]

# %%
#using loc[] with columns
df.loc[50:60 , ['budget','genres','runtime']]
# Out:
#        budget                                             genres  runtime
# 50     560000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...    102.0
# 51   12000000  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...    160.0
# 52          0  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...     97.0
# 53          0  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...     98.0
# 54   20000000                     [{'id': 28, 'name': 'Action'}]    107.0
# 55          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     95.0
# 56          0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...     97.0
# 57  125000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...    125.0
# 58          0  [{'id': 10402, 'name': 'Music'}, {'id': 10749,...     95.0
# 59   14000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...     95.0
# 60  150000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...    144.0

# %%
df.loc[:,['budget','genres','runtime','original_title']]
# Out:
#         budget                                             genres  runtime  \
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]     93.0
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    113.0
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]    105.0
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...    122.0
# 4            0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...    118.0
# ...        ...                                                ...      ...
# 2995         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...    102.0
# 2996         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...    102.0
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...    120.0
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...     90.0
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...    106.0
#
#                                 original_title
# ...

# %% [markdown]
# We can do in another way

# %%
df[['budget','genres','runtime','original_title']]
# Out:
#         budget                                             genres  runtime  \
# 0     14000000                     [{'id': 35, 'name': 'Comedy'}]     93.0
# 1     40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...    113.0
# 2      3300000                      [{'id': 18, 'name': 'Drama'}]    105.0
# 3      1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...    122.0
# 4            0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...    118.0
# ...        ...                                                ...      ...
# 2995         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...    102.0
# 2996         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...    102.0
# 2997  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...    120.0
# 2998  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...     90.0
# 2999  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...    106.0
#
#                                 original_title
# ...

# %% [markdown]
# Doing Slicing for Row and Index

# %%
df.iloc[:,-3:]
# Out:
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# ...

# %% [markdown]
# Indexing for rows

# %%
df.iloc[3]
# Out:
# id                                                                       4
# belongs_to_collection                                                  NaN
# budget                                                             1200000
# genres                   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# homepage                                        http://kahaanithefilm.com/
# imdb_id                                                          tt1821480
# original_language                                                       hi
# original_title                                                     Kahaani
# overview                 Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# popularity                                                        3.174936
# poster_path                               /aTXRaPrWSinhcmCrcfJK17urp3F.jpg
# production_companies                                                   NaN
# ...

# %% [markdown]
# Accessing columns with multiple rows and single column through indexing.

# %%
df.iloc[:,-1]
# Out:
# 0        12314651
# 1        95149435
# 2        13092000
# 3        16000000
# 4         3923970
#           ...
# 2995      1596687
# 2996       180590
# 2997     89456761
# 2998    171963386
# 2999     82087155
# Name: revenue, Length: 3000, dtype: int64

# %% [markdown]
# Accessing columns with multiple rows and single column through column name using loc() fn.

# %%
df.loc[:,['budget']]
# Out:
#         budget
# 0     14000000
# 1     40000000
# 2      3300000
# 3      1200000
# 4            0
# ...        ...
# 2995         0
# 2996         0
# 2997  65000000
# 2998  42000000
# 2999  35000000
#
# [3000 rows x 1 columns]

# %%
df.loc[2]
# Out:
# id                                                                       3
# belongs_to_collection                                                  NaN
# budget                                                             3300000
# genres                                       [{'id': 18, 'name': 'Drama'}]
# homepage                                 http://sonyclassics.com/whiplash/
# imdb_id                                                          tt2582802
# original_language                                                       en
# original_title                                                    Whiplash
# overview                 Under the direction of a ruthless instructor, ...
# popularity                                                        64.29999
# poster_path                               /lIv1QinFqz4dlp5U4lQ6HaiskOZ.jpg
# production_companies     [{'name': 'Bold Films', 'id': 2266}, {'name': ...
# ...

# %% [markdown]
# **If you wanted a new column**

# %%
df.loc[:,'half_runtime'] = df.loc[: , 'runtime'] * 0.5
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# **Writing code in another way**

# %%
df['half_runtime'] = df['runtime'] * 0.5
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %%
df.rename(columns={'half_runtime':'h_runtime' },inplace=True)
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# **Drop() Function** : Removing column

# %%
df.drop(columns = ['h_runtime'],inplace = True)
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...

# %% [markdown]
# **Drop() Function** : Removing rows

# %%
import pandas as pd

# Example DataFrame
df1 = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6]})

# Drop the row at index 1
df2 = df1.drop(1)
df2
# Out:
#    A  B
# 0  1  4
# 2  3  6

# %%
df.drop(0,inplace=True)
df
# Out:
#         id                              belongs_to_collection    budget  \
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# 5        6                                                NaN   8000000
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# ...
